# %% [markdown]
# # IMPORT DATA
#
# ### Import the file "load_data" and call the method load_data
#
# The main method, called "load_data", takes as input a folder ( according to the specific of Benchmark Data Sets for Graph Kernels from "technische universitat dortmund" --> link: https://ls11-www.cs.tu-dortmund.de/staff/morris/graphkerneldatasets)
#
# It returns a list of pairs, each pairs is a graph, label

# %% [markdown]
# ### Import libraries

# %%
import load_data as ld

graphs = ld.load_data("MUTAG")

# %%
graphs[1:5]
# Out:
# [[<networkx.classes.graph.Graph at 0x1dcf5ca9cc0>, 0],
#  [<networkx.classes.graph.Graph at 0x1dcf5cdd588>, 0],
#  [<networkx.classes.graph.Graph at 0x1dcf5f38eb8>, 1],
#  [<networkx.classes.graph.Graph at 0x1dcf5f4b4a8>, 0]]

# %% [markdown]
# ### Show the graph using EDeN

# %%
from eden.display import draw_graph
draw_graph(graphs[0][0],  size=15, vertex_size=1500, font_size=14, vertex_border=True, size_x_to_y_ratio=3)
# Out:
# C:\Users\longa\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
