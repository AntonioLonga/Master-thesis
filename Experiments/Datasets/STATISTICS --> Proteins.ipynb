# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import HTML
HTML('<style>.container { width:97% !important; }</style><style>.output_png {display: table-cell;text-align: center;vertical-align: middle;}</style>')
# Out:
# <style>.container { width:97% !important; }</style><style>.output_png {display: table-cell;text-align: center;vertical-align: middle;}</style>

# %%
import dataset_statistics as dstat

# %% [markdown]
# ## COX2

# %%
dstat.summary("COX2")
# Out:
# DATASET: 	 COX2

# %%
dstat.summary("COX2_MD")
# Out:
# DATASET: 	 COX2_MD

# %% [markdown]
# ## DHFR

# %%
dstat.summary("DHFR")
# Out:
# DATASET: 	 DHFR

# %%
dstat.summary("DHFR_MD")
# Out:
# DATASET: 	 DHFR_MD

# %% [markdown]
# ## PROTEINS

# %%
dstat.summary("PROTEINS")
# Out:
# DATASET: 	 PROTEINS
